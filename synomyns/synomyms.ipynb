# %% [markdown]
# ## 中文近义词包

# %%
# 中文分词

import synonyms
synonyms.seg("中文近义词工具包")
# Out:
# smart_open library not found; falling back to local-filesystem-only
# Building prefix dict from /home/xyf/anaconda3/envs/python36/lib/python3.6/site-packages/synonyms/data/vocab.txt ...
# >> Synonyms load wordseg dict [/home/xyf/anaconda3/envs/python36/lib/python3.6/site-packages/synonyms/data/vocab.txt] ...
# Dumping model to file cache /tmp/jieba.u425e10780cebfc5dce7898be55b531a4.cache
# Loading model cost 1.710 seconds.
# Prefix dict has been built succesfully.
# >> Synonyms on loading stopwords [/home/xyf/anaconda3/envs/python36/lib/python3.6/site-packages/synonyms/data/stopwords.txt] ...
# >> Synonyms on loading vectors [/home/xyf/anaconda3/envs/python36/lib/python3.6/site-packages/synonyms/data/words.vector] ...
# (['中文', '近义词', '工具包'], ['nz', 'n', 'n'])

# %%
# 近义词

import synonyms
print("人脸:", (synonyms.nearby("人脸")))
print("识别:", (synonyms.nearby("识别")))

# 返回两个列表,列表一是近义词们,按照距离的长度由近及远排列，列表二是中对应位置的词的距离的分数，分数在(0-1)区间内，越接近于1，代表越相近。


# 获取近义词2
synonyms.display("飞机")
# Out:
# 人脸: (['人脸', '图片', '通过观察', '几何图形', '图象', '放大镜', '面孔', '貌似', '奇特', '十分相似'], [1.0, 0.5972837, 0.56848586, 0.53183466, 0.5253439, 0.5240093, 0.52310055, 0.5006411, 0.4851142, 0.39761636])
# 识别: (['识别', '辨识', '辨别', '辨认', '标识', '鉴别', '标记', '识别系统', '比对', '定位'], [1.0, 0.8722487, 0.76409876, 0.72576123, 0.7029182, 0.68861014, 0.6781318, 0.6638289, 0.5903494, 0.56316423])
# '飞机'近义词：
#   1. 飞机:1.0
#   2. 架飞机:0.8373988
#   3. 直升机:0.762116
#   4. 民航机:0.7505188
#   5. 航机:0.7501163
#   6. 起飞:0.7357359
#   7. 飞行中:0.7326494
#   8. 航空器:0.72394454
#   9. 军用飞机:0.7153115
#   10. B-:0.7099306

# %%
# 两个句子的相似度比较
# 旗帜引领方向 vs 道路决定命运: 0.429
# 旗帜引领方向 vs 旗帜指引道路: 0.93
# 发生历史性变革 vs 发生历史性变革: 1.0

sen1 = "旗帜引领方向"
sen2 = "旗帜指引道路"
r = synonyms.compare(sen1, sen2, seg=True)  #seg表示s
print(r)
# Out:
# 0.445

# %%
# 获得一个词语的向量，该向量为numpy的array，当该词语是未登录词时，抛出 KeyError异常。

synonyms.v("飞机")
# Out:
# array([-2.412167  ,  2.2628384 , -7.0214124 ,  3.9381874 ,  0.8219283 ,
#         1.2295285 ,  2.094081  ,  3.3323638 , -4.510823  , -5.0665236 ,
#         0.02842946, -3.3997178 , -1.2039514 , -0.41965684,  3.8030207 ,
#        -2.7703528 , -3.3377292 , -0.53231865,  3.0771294 , -2.8605607 ,
#         4.0985856 ,  4.90407   ,  5.1674056 , -4.296228  ,  5.238932  ,
#        -1.2872986 , -2.6919281 , -1.265456  ,  4.357783  , -3.152784  ,
#        -1.8253915 , -0.26429367,  4.7812095 , -3.0076027 ,  1.1862044 ,
#        -4.0748215 , -2.0850594 ,  2.7078238 ,  0.5801922 , -2.6405838 ,
#        -4.2036343 ,  5.115869  ,  6.628398  , -0.4762851 , -0.12237136,
#         5.9480147 ,  2.0498013 , -1.8562602 ,  1.7544835 ,  1.2337459 ,
#         3.674985  ,  0.47799912, -2.3083916 ,  3.359072  , -3.055417  ,
#         1.8654342 ,  0.94236475, -2.3830638 ,  0.6508183 , -1.0955038 ,
#        -4.9752293 , -4.1217375 ,  1.6156564 ,  0.24526696, -5.1201544 ,
#         4.929091  , -1.6367353 , -0.22766887,  4.568321  ,  1.3573635 ,
#        -0.6158356 ,  4.698002  ,  3.4604642 ,  4.7021303 ,  1.7896692 ,
#         1.9929938 ,  3.2132697 , -1.9496875 , -0.13856182, -2.0966465 ,
#         0.933619  ,  2.4530976 ,  7.36157   , -0.27288303, -0.785315  ,
#         4.141208  ,  2.1583297 , -3.8057325 , -1.6597345 ,  1.5907892 ,
#        -0.66101193,  5.272054  ,  2.8616483 ,  4.2360854 ,  5.903472  ,
#        -3.2809453 ,  3.8747153 , -5.217062  , -2.2786229 , -1.2572327 ],
#       dtype=float32)

# %%
# 获得一个分词后句子的向量，向量以BoW方式组成

# sentence: 句子是分词后通过空格联合起来
# ignore: 是否忽略OOV，False时，随机生成一个向量
sentence = '我很开心'
synonyms.sv(sentence, ignore=False)
# Out:
# [array([-0.7387598 ,  0.12181167,  0.11952854,  0.35497192,  0.92974466,
#         -0.08026054, -0.957836  , -0.29619652,  0.04995187,  1.4094759 ,
#          0.54402584,  0.3165929 , -0.4181194 ,  0.7492943 ,  1.5599262 ,
#         -0.29743868,  2.0216784 ,  0.05676674,  0.02384092,  0.32189   ,
#          0.51653045, -0.5260381 ,  0.7942444 , -3.327997  , -0.16860853,
#          0.4444737 , -0.20984569, -0.49785674,  0.5157778 , -0.3329211 ,
#         -1.2175868 ,  0.7678592 , -0.2282597 , -1.7364593 , -0.89566845,
#         -0.21831198,  0.33145764,  0.22352308,  0.980378  ,  0.65484196,
#          0.6013849 ,  1.2343655 , -1.5362965 , -1.3499529 ,  0.30794466,
